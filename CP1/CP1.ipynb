# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.optimize as optimize


#Daten Laden und ausgeben
data=np.loadtxt("madelung.txt")
data2=np.loadtxt("madelungFlach.txt")
# print(data) 

#Spalten der Datei auslesen
Anzahl = data[:,0] #1.Spalte Anzahl der Elemente pro Reihe
Energie = data[:,1] #2.Spalte V_i Energie
Energie2=data2[:,1]

ydata = Energie
ydata2=Energie2
xdata=Anzahl

# nun erschaffen wir einen plot
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)

# Erste Abbildung 
# Die Achsen brauchen auf jeden Fall eine Beschriftung
plt.title('Madelung-Energie des  NaCl Kristall',fontsize=20)
plt.ylabel('Madelungsenergie eines Bausteins *a', fontsize = 16)
plt.xlabel('Anzahl gesamte Elemente', fontsize = 16)
plt.xlim(xdata[0]-1,xdata[-1]+1)
# plt.ylim(-5*10**-28,-2.5*10**-28)
plt.grid()
plt.scatter(xdata,ydata,color='blue')
plt.plot(xdata,-4.031767046*10**-28+0*xdata,linestyle="dotted",color='red')

# Zeige den Plot
plt.show()


# Zweite Abbildung -Flaches Kristall
# nun erschaffen wir einen plot
fig = plt.figure(figsize=(20, 10))
ax = fig.add_subplot(111)

# Erste Abbildung 
# Die Achsen brauchen auf jeden Fall eine Beschriftung
plt.title('Madelung-Energie des  NaCl Kristall',fontsize=20)
plt.ylabel('Madelungsenergie eines Bausteins *a', fontsize = 16)
plt.xlabel('Anzahl gesamte Elemente', fontsize = 16)
plt.xlim(xdata[0]-1,xdata[-1]+1)
# plt.ylim(-5*10**-28,-2.5*10**-28)
plt.grid()
plt.scatter(xdata,ydata,color='blue')
plt.plot(xdata,-4.031767046*10**-28+0*xdata,linestyle="dotted",color='red')

# Zeige den Plot
plt.show()
